# %% [markdown]
# # PREDICT A STUDENT'S FINAL EXAM SCORE BASED ON THE NUMBER OF HOURS THEY STUDY?

# %%
# step - 1

import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# step - 2
shared_data = {"hour_study" : [2,3,4,5,6,7,8,9,10], "exam_score" : [50,60,70,75,80,85,90,92,95]}

# step - 3
df = pd.DataFrame(shared_data)

# step - 4
x = df[['hour_study']]
y = df[["exam_score"]]

# step - 5
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# step - 6
model = LinearRegression()

# step - 7
model.fit(x_train, y_train)

# user_input_testing 
user_input = float(input("Enter the number of hours you study - "))

predict_score = model.predict([[user_input]])

# printing the output 
print(f"Predicted exam score  - {predict_score[0][0]:.2f}")
# Out:
# Enter the number of hours you study -  11
# Predicted exam score  - 105.24
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#    hour_study  exam_score
# 0           2          50
# 1           3          60
# 2           4          70
# 3           5          75
# 4           6          80
# 5           7          85
# 6           8          90
# 7           9          92
# 8          10          95
